# %% [markdown]
# <a href="https://colab.research.google.com/github/NyalamSaiPrashanth/2311CS020486-SIGMA/blob/main/Student_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("/content/student-data-csv-metadata.json")
print(df.head())
# Out:
# Empty DataFrame
# ...

# %%
print(df.shape)
print(df.info())
# Out:
# (0, 268)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Columns: 268 entries, {"@context":{"@language":"en" to description:""}
# dtypes: object(268)
# memory usage: 132.0+ bytes
# None

# %%
sampled_df = df.sample(frac=0.6, random_state=42)
print(sampled_df)
# Out:
# Empty DataFrame
# ...

# %%
print(df.columns)
# Out:
# Index(['{"@context":{"@language":"en"', '@vocab:"https://schema.org/"',
#        'citeAs:"cr:citeAs"', 'column:"cr:column"',
#        'conformsTo:"dct:conformsTo"', 'cr:"http://mlcommons.org/croissant/"',
#        'data:{"@id":"cr:data"', '@type:"@json"}', 'dataBiases:"cr:dataBiases"',
#        'dataCollection:"cr:dataCollection"',
#        ...
#        'name:"Kaggle".1', 'url:"https://www.kaggle.com/organizations/kaggle"',
#        'image:"https://storage.googleapis.com/kaggle-organizations/4/thumbnail.png"}',
#        'thumbnailUrl:"https://storage.googleapis.com/kaggle-datasets-images/new-version-temp-images/default-backgrounds-34.png-12558235/dataset-card.png"',
#        'dateModified:"2024-02-22T14:15:10.253"',
#        'datePublished:"2024-02-22T14:15:10.253"', '@type:"sc:Dataset"',
#        'name:"student-data.csv"',
#        'url:"https://www.kaggle.com/datasets/kellygakii/student-data-csv/versions/1"',
#        'description:""}'],
#       dtype='object', length=268)
